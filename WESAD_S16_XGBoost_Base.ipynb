# %% [markdown]
# # S16  WESAD XGBoost

# %% [markdown]
#     Male Participant
#     Age: 24
#     Height (cm): 184
#     Weight (kg): 69
#     Note: cold during Stress Conditioning

# %% [markdown]
# **This notebook contains exploratory data analyses and the model run explorations**

# %% [markdown]
# **Notes**

# %% [markdown]
# **Which feature or combination of features best predict stress?**
#
# **Exclude classes 5, 6, and 7**
#
# **Chosen Subjects**
# 1. Female - S8 (cold during stress)
# 2. Female - S11
# 3. Female - S17
# 4. Male - S13
# 5. Male - S16 (cold during stress)
# 6. Male - S4

# %% [markdown]
# **Notebooks**
#
# WESAD_S16_XGBoost_Base<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S16_XGBoost_Base.ipynb
#
# WESAD_S4_XGBoost<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S4_XGBoost.ipynb
#
# WESAD_S8_XGBoost<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S8_XGBoost.ipynb
#
# WESAD_S11_XGBoost<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S11_XGBoost.ipynb
#
# WESAD_S13_XGBoost<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S13_XGBoost.ipynb
#
# WESAD_S17_XGBoost<BR>
# https://github.com/wmadisonf/WESAD_Sensory_Classification_XGBoost/blob/master/WESAD_S17_XGBoost.ipynb

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-Tools" data-toc-modified-id="Load-Tools-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load Tools</a></span></li><li><span><a href="#2-Load-and-Process-File" data-toc-modified-id="2-Load-and-Process-File-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2 Load and Process File</a></span><ul class="toc-item"><li><span><a href="#Load-File" data-toc-modified-id="Load-File-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load File</a></span></li><li><span><a href="#Process" data-toc-modified-id="Process-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Process</a></span><ul class="toc-item"><li><span><a href="#Seperate-chest-features--from-wrist--features" data-toc-modified-id="Seperate-chest-features--from-wrist--features-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Seperate chest features  from wrist  features</a></span></li><li><span><a href="#Check-if-all-chest-feature-length-are-equal" data-toc-modified-id="Check-if-all-chest-feature-length-are-equal-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Check if all chest feature length are equal</a></span></li><li><span><a href="#Seperate-wrist-features--from--chest-features" data-toc-modified-id="Seperate-wrist-features--from--chest-features-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Seperate wrist features  from  chest features</a></span><ul class="toc-item"><li><span><a href="#Check-if-all-wrist-feature-length-are-equal" data-toc-modified-id="Check-if-all-wrist-feature-length-are-equal-2.2.3.1"><span class="toc-item-num">2.2.3.1&nbsp;&nbsp;</span>Check if all wrist feature length are equal</a></span></li><li><span><a href="#Compare-wrist-feature-lengths" data-toc-modified-id="Compare-wrist-feature-lengths-2.2.3.2"><span class="toc-item-num">2.2.3.2&nbsp;&nbsp;</span>Compare wrist feature lengths</a></span></li></ul></li><li><span><a href="#Change-dictionary-object-to-a-numpy-array-and-array-to-a-dataframe" data-toc-modified-id="Change-dictionary-object-to-a-numpy-array-and-array-to-a-dataframe-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Change dictionary object to a numpy array and array to a dataframe</a></span><ul class="toc-item"><li><span><a href="#Check-Statistics" data-toc-modified-id="Check-Statistics-2.2.4.1"><span class="toc-item-num">2.2.4.1&nbsp;&nbsp;</span>Check Statistics</a></span></li><li><span><a href="#Check-Type" data-toc-modified-id="Check-Type-2.2.4.2"><span class="toc-item-num">2.2.4.2&nbsp;&nbsp;</span>Check Type</a></span></li><li><span><a href="#Check-class-counts" data-toc-modified-id="Check-class-counts-2.2.4.3"><span class="toc-item-num">2.2.4.3&nbsp;&nbsp;</span>Check class counts</a></span></li><li><span><a href="#Show-label-classes-sequence-plot" data-toc-modified-id="Show-label-classes-sequence-plot-2.2.4.4"><span class="toc-item-num">2.2.4.4&nbsp;&nbsp;</span>Show label classes sequence plot</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Grouped-classes-graphs" data-toc-modified-id="Grouped-classes-graphs-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Grouped classes graphs</a></span><ul class="toc-item"><li><span><a href="#Group-by" data-toc-modified-id="Group-by-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Group by</a></span></li><li><span><a href="#Accelerometer-graph" data-toc-modified-id="Accelerometer-graph-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Accelerometer graph</a></span></li><li><span><a href="#EDA,-TEMP,-RESP-graphs" data-toc-modified-id="EDA,-TEMP,-RESP-graphs-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>EDA, TEMP, RESP graphs</a></span></li><li><span><a href="#ECG-and-EMG-graphs" data-toc-modified-id="ECG-and-EMG-graphs-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>ECG and EMG graphs</a></span></li></ul></li><li><span><a href="#Concatenate-classes-0,-1,-2,-3,-and-4" data-toc-modified-id="Concatenate-classes-0,-1,-2,-3,-and-4-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Concatenate classes 0, 1, 2, 3, and 4</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Plot-classes-0,1,2,3,4--vs.-all-classes" data-toc-modified-id="Plot-classes-0,1,2,3,4--vs.-all-classes-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Plot classes 0,1,2,3,4  vs. all classes</a></span></li><li><span><a href="#Correlation-Plot" data-toc-modified-id="Correlation-Plot-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Correlation Plot</a></span></li><li><span><a href="#Pairs-plots" data-toc-modified-id="Pairs-plots-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Pairs plots</a></span></li><li><span><a href="#Histogram-with-Boxplot" data-toc-modified-id="Histogram-with-Boxplot-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Histogram with Boxplot</a></span></li></ul></li><li><span><a href="#Model-allChest:-All-chest-features" data-toc-modified-id="Model-allChest:-All-chest-features-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model allChest: All chest features</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Check-Train-Correlations" data-toc-modified-id="Check-Train-Correlations-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Check Train Correlations</a></span></li><li><span><a href="#Model-Fit" data-toc-modified-id="Model-Fit-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Model Fit</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><span><a href="#Balanced-Accuracy-and-Classification-Report" data-toc-modified-id="Balanced-Accuracy-and-Classification-Report-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Balanced Accuracy and Classification Report</a></span></li><li><span><a href="#Multi-class-Error-Plot" data-toc-modified-id="Multi-class-Error-Plot-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Multi-class Error Plot</a></span></li><li><span><a href="#cross-validation-and-scaling-check" data-toc-modified-id="cross-validation-and-scaling-check-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>cross validation and scaling check</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-6.4.4"><span class="toc-item-num">6.4.4&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#Class-Prediction-Error" data-toc-modified-id="Class-Prediction-Error-6.4.5"><span class="toc-item-num">6.4.5&nbsp;&nbsp;</span>Class Prediction Error</a></span></li><li><span><a href="#Multi-class-AUC-Score" data-toc-modified-id="Multi-class-AUC-Score-6.4.6"><span class="toc-item-num">6.4.6&nbsp;&nbsp;</span>Multi-class AUC Score</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-6.4.7"><span class="toc-item-num">6.4.7&nbsp;&nbsp;</span>Feature Importance</a></span></li></ul></li></ul></li><li><span><a href="#Model-shortChest:-Less-Electromyogram" data-toc-modified-id="Model-shortChest:-Less-Electromyogram-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model shortChest: Less Electromyogram</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Model-Fit" data-toc-modified-id="Model-Fit-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Model Fit</a></span></li><li><span><a href="#Balanced-Accuracy-and-Classification-Report" data-toc-modified-id="Balanced-Accuracy-and-Classification-Report-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Balanced Accuracy and Classification Report</a></span></li><li><span><a href="#Multi-class-Error-Plot" data-toc-modified-id="Multi-class-Error-Plot-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Multi-class Error Plot</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#Classification-Prediction-Error" data-toc-modified-id="Classification-Prediction-Error-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Classification Prediction Error</a></span></li><li><span><a href="#Multiclass-ROC-AUC-Score" data-toc-modified-id="Multiclass-ROC-AUC-Score-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Multiclass ROC AUC Score</a></span></li></ul></li><li><span><a href="#Model-ch_lessAcc:-Chest-Less-Accelerometer" data-toc-modified-id="Model-ch_lessAcc:-Chest-Less-Accelerometer-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model ch_lessAcc: Chest Less Accelerometer</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Model-Fit,-Classification-report,-and-Balanced-Accuracy" data-toc-modified-id="Model-Fit,-Classification-report,-and-Balanced-Accuracy-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Model Fit, Classification report, and Balanced Accuracy</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#Classification-Prediction-Error" data-toc-modified-id="Classification-Prediction-Error-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Classification Prediction Error</a></span></li><li><span><a href="#Multiclass-ROC-AUC-Score" data-toc-modified-id="Multiclass-ROC-AUC-Score-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Multiclass ROC AUC Score</a></span></li></ul></li><li><span><a href="#Model-ACC:-Accelerometer-[X,Y,Z]" data-toc-modified-id="Model-ACC:-Accelerometer-[X,Y,Z]-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Model ACC: Accelerometer [X,Y,Z]</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Model-Fit-and-f1-and-Balanced-Accuracy-Scores" data-toc-modified-id="Model-Fit-and-f1-and-Balanced-Accuracy-Scores-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Model Fit and f1 and Balanced Accuracy Scores</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Classification-Prediction-Error" data-toc-modified-id="Classification-Prediction-Error-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Classification Prediction Error</a></span></li><li><span><a href="#Multiclass-ROC-AUC-Score" data-toc-modified-id="Multiclass-ROC-AUC-Score-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Multiclass ROC AUC Score</a></span></li></ul></li><li><span><a href="#Individual-Features" data-toc-modified-id="Individual-Features-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Individual Features</a></span><ul class="toc-item"><li><span><a href="#Model-Eda:-Electrodermal-Activity-only" data-toc-modified-id="Model-Eda:-Electrodermal-Activity-only-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Model Eda: Electrodermal Activity only</a></span><ul class="toc-item"><li><span><a href="#Test-Train-Split" data-toc-modified-id="Test-Train-Split-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>Test Train Split</a></span></li><li><span><a href="#Model-Fit,-classification-report,-and-balanced-accuracy" data-toc-modified-id="Model-Fit,-classification-report,-and-balanced-accuracy-10.1.2"><span class="toc-item-num">10.1.2&nbsp;&nbsp;</span>Model Fit, classification report, and balanced accuracy</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-10.1.3"><span class="toc-item-num">10.1.3&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Classification-Prediction-Error" data-toc-modified-id="Classification-Prediction-Error-10.1.4"><span class="toc-item-num">10.1.4&nbsp;&nbsp;</span>Classification Prediction Error</a></span></li><li><span><a href="#Multiclass-ROC-AUC-Score" data-toc-modified-id="Multiclass-ROC-AUC-Score-10.1.5"><span class="toc-item-num">10.1.5&nbsp;&nbsp;</span>Multiclass ROC AUC Score</a></span></li></ul></li><li><span><a href="#Model-Temp:-Skin-Temperature" data-toc-modified-id="Model-Temp:-Skin-Temperature-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Model Temp: Skin Temperature</a></span><ul class="toc-item"><li><span><a href="#Test-Train-Split" data-toc-modified-id="Test-Train-Split-10.2.1"><span class="toc-item-num">10.2.1&nbsp;&nbsp;</span>Test Train Split</a></span></li><li><span><a href="#Model-Fit,-classification-report,-and-Balanced-Accuracy" data-toc-modified-id="Model-Fit,-classification-report,-and-Balanced-Accuracy-10.2.2"><span class="toc-item-num">10.2.2&nbsp;&nbsp;</span>Model Fit, classification report, and Balanced Accuracy</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-10.2.3"><span class="toc-item-num">10.2.3&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Classification-Prediction-Error" data-toc-modified-id="Classification-Prediction-Error-10.2.4"><span class="toc-item-num">10.2.4&nbsp;&nbsp;</span>Classification Prediction Error</a></span></li><li><span><a href="#Multiclass-ROC-AUC-Score" data-toc-modified-id="Multiclass-ROC-AUC-Score-10.2.5"><span class="toc-item-num">10.2.5&nbsp;&nbsp;</span>Multiclass ROC AUC Score</a></span></li></ul></li></ul></li><li><span><a href="#Statistics" data-toc-modified-id="Statistics-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Statistics</a></span><ul class="toc-item"><li><span><a href="#Macro-Average-Scores,-Mean,-and-Standard-Deviation-across-4-Subjects" data-toc-modified-id="Macro-Average-Scores,-Mean,-and-Standard-Deviation-across-4-Subjects-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Macro Average Scores, Mean, and Standard Deviation across 4 Subjects</a></span></li><li><span><a href="#Stress-condition-scores" data-toc-modified-id="Stress-condition-scores-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Stress condition scores</a></span><ul class="toc-item"><li><span><a href="#across-all-4-Subjects" data-toc-modified-id="across-all-4-Subjects-11.2.1"><span class="toc-item-num">11.2.1&nbsp;&nbsp;</span>across all 4 Subjects</a></span></li><li><span><a href="#Comfort-during-Stress-f1-scores" data-toc-modified-id="Comfort-during-Stress-f1-scores-11.2.2"><span class="toc-item-num">11.2.2&nbsp;&nbsp;</span>Comfort during Stress f1 scores</a></span></li></ul></li><li><span><a href="#Stress-vs" data-toc-modified-id="Stress-vs-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Stress vs</a></span><ul class="toc-item"><li><span><a href="#Gender-Stress-f1-scores" data-toc-modified-id="Gender-Stress-f1-scores-11.3.1"><span class="toc-item-num">11.3.1&nbsp;&nbsp;</span>Gender Stress f1 scores</a></span></li><li><span><a href="#Stress-vs-Baseline" data-toc-modified-id="Stress-vs-Baseline-11.3.2"><span class="toc-item-num">11.3.2&nbsp;&nbsp;</span>Stress vs Baseline</a></span><ul class="toc-item"><li><span><a href="#Graph-Stress-vs-Baseline" data-toc-modified-id="Graph-Stress-vs-Baseline-11.3.2.1"><span class="toc-item-num">11.3.2.1&nbsp;&nbsp;</span>Graph Stress vs Baseline</a></span></li><li><span><a href="#Mean-Stress-vs-Baseline" data-toc-modified-id="Mean-Stress-vs-Baseline-11.3.2.2"><span class="toc-item-num">11.3.2.2&nbsp;&nbsp;</span>Mean Stress vs Baseline</a></span></li></ul></li><li><span><a href="#Graph-Stress-vs-Baseline-by-Gender" data-toc-modified-id="Graph-Stress-vs-Baseline-by-Gender-11.3.3"><span class="toc-item-num">11.3.3&nbsp;&nbsp;</span>Graph Stress vs Baseline by Gender</a></span><ul class="toc-item"><li><span><a href="#Mean-stress-female-vs-male" data-toc-modified-id="Mean-stress-female-vs-male-11.3.3.1"><span class="toc-item-num">11.3.3.1&nbsp;&nbsp;</span>Mean stress female vs male</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Load Tools

# %%
# %matplotlib inline
import pickle
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#pip install xlrd

# %%
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import balanced_accuracy_score, f1_score, roc_auc_score 
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler, label_binarize
from sklearn.utils import class_weight
import xgboost as xgb
from xgboost import plot_importance, XGBClassifier

# %%
# Visualizing High-Performance Gradient Boosting with XGBoost and Yellowbrick
# https://rebeccabilbro.github.io/xgboost-and-yellowbrick/
# conda install -c districtdatalabs yellowbrick

from yellowbrick.classifier import ClassBalance, ROCAUC, ClassificationReport, ClassPredictionError

# %%
sns.set(style="darkgrid")

# %%
import autoreload
# %load_ext watermark
# %load_ext autoreload
# %autoreload 2
# %watermark -a 'WForsythe' -d -t -v -p   numpy,pandas,cv2,xgboost,sklearn,seaborn,matplotlib,yellowbrick
# Out:
# WForsythe 2020-07-31 05:07:37
#
# CPython 3.7.6
# IPython 7.11.1
#
# numpy 1.18.1
# pandas 1.0.3
# cv2 4.2.0
# xgboost 1.0.2
# sklearn 0.22.1
# seaborn 0.9.0
# matplotlib 3.2.2
# yellowbrick 1.1

# %% [markdown]
# ## 2 Load and Process File

# %% [markdown]
# ### Load File

# %%
data = 'D:/WESAD/'
s16_file = pd.read_pickle(data + 'S16/S16.pkl')
s16_file
# Out:
# {'signal': {'chest': {'ACC': array([[ 0.71599996,  0.08560002,  1.6184001 ],
#           [ 0.60759997,  0.03919995,  1.51920009],
#           [ 0.52520001, -0.01419997,  1.31520009],
#           ...,
#           [ 0.90820003, -0.02100003, -0.14539999],
#           [ 0.90740001, -0.0194    , -0.14539999],
#           [ 0.90480006, -0.0194    , -0.14539999]]),
#    'ECG': array([[ 0.05278015],
#           [ 0.01853943],
#           [-0.03712463],
#           ...,
#           [-0.0426178 ],
#           [-0.03570557],
#           [-0.02810669]]),
#    'EMG': array([[-0.03744507],
#           [ 0.00682068],
#           [ 0.02906799],
#           ...,
#           [-0.01277161],
#           [-0.00352478],
#           [ 0.01075745]]),
#    'EDA': array([[0.96321106],
#           [0.94642639],
#           [0.9803772 ],
#           ...,
#           [2.07595825],
#           [2.07061768],
#           [2.06985474]]),
#    'Temp': array([[33.405396],
#           [33.42804 ],
# ...

# %% [markdown]
# **there are 3 columns for both chest and wrist ACC and one column each for the other features**

# %% [markdown]
# ### Process

# %% [markdown]
# #### Seperate chest features  from wrist  features

# %%
cax = s16_file['signal']['chest']['ACC'][0:,0]
cay = s16_file['signal']['chest']['ACC'][0:,1]
caz = s16_file['signal']['chest']['ACC'][0:,2]
cecg = s16_file['signal']['chest']['ECG'][:,0]
cemg = s16_file['signal']['chest']['EMG'][:,0]
ceda = s16_file['signal']['chest']['EDA'][:,0]
ctemp = s16_file['signal']['chest']['Temp'][:,0]
cresp = s16_file['signal']['chest']['Resp'][:,0]
label = s16_file['label']

# %%
label
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# #### Check if all chest feature length are equal

# %%
#https://stackoverflow.com/questions/16720844/compare-length-of-three-lists-in-python
import itertools
chest_list_all = [cax,cay,caz,cecg,cemg,ceda,ctemp,cresp,label]
chest_length = all([len(a)==len(b) for a,b in list(itertools.combinations(chest_list_all,2))])
print(chest_length)
print(len(label))
# Out:
# True
# 3941700

# %% [markdown]
# #### Seperate wrist features  from  chest features

# %%
wax = s16_file['signal']['wrist']['ACC'][0:,0]
way = s16_file['signal']['wrist']['ACC'][0:,1]
waz = s16_file['signal']['wrist']['ACC'][0:,2]
weda = s16_file['signal']['wrist']['EDA'][:,0]
wtemp = s16_file['signal']['wrist']['TEMP'][:,0]
wbvp = s16_file['signal']['wrist']['BVP'][:,0]
label = s16_file['label']

# %% [markdown]
# ##### Check if all wrist feature length are equal

# %%
wrist_list = [wax,way,waz,weda,wtemp,wbvp]
wrist_length = all([len(a)==len(b) for a,b in list(itertools.combinations(wrist_list,2))])
wrist_length
# Out:
# False

# %% [markdown]
# ##### Compare wrist feature lengths

# %%
wrist_ACC = [wax,way,waz]
wrist_length_ACC = all([len(a)==len(b) for a, b in list(itertools.combinations(wrist_ACC,2))])
print(len(wax), len(way), len(waz))
print(len(weda), len(wtemp), len(wbvp))
# Out:
# 180192 180192 180192
# 22524 22524 360384

# %% [markdown]
# #### Change dictionary object to a numpy array and array to a dataframe

# %%
# Python | Numpy ndarray.T
# https://www.geeksforgeeks.org/python-numpy-ndarray-t/
# Numpy Array Cookbook: Generating and Manipulating Arrays in Python
# https://towardsdatascience.com/numpy-array-cookbook-generating-and-manipulating-arrays-in-python-2195c3988b09

# %%
chest = [cax, cay, caz, cecg, cemg, 
         ceda, ctemp, cresp, label] 
ch_array = np.array(chest) 
ch_array = ch_array.T # transpose 
Columns = ['cax', 'cay', 'caz','cecg', 'cemg', 
          'ceda','ctemp', 'cresp', 'label' ]
ch_df = pd.DataFrame(ch_array, columns = Columns) 
ch_df
# Out:
#             cax     cay     caz      cecg      cemg      ceda      ctemp  \
# 0        0.7160  0.0856  1.6184  0.052780 -0.037445  0.963211  33.405396
# 1        0.6076  0.0392  1.5192  0.018539  0.006821  0.946426  33.428040
# 2        0.5252 -0.0142  1.3152 -0.037125  0.029068  0.980377  33.408447
# 3        0.4800 -0.0718  1.0126 -0.082260  0.002884  0.954437  33.420502
# 4        0.4638 -0.1342  0.6410 -0.101624 -0.014603  0.947571  33.414459
# ...         ...     ...     ...       ...       ...       ...        ...
# 3941695  0.9088 -0.0206 -0.1426 -0.045319 -0.026276  2.178955  34.260315
# 3941696  0.9078 -0.0212 -0.1480 -0.040878 -0.018997  2.083969  34.289337
# 3941697  0.9082 -0.0210 -0.1454 -0.042618 -0.012772  2.075958  34.319916
# 3941698  0.9074 -0.0194 -0.1454 -0.035706 -0.003525  2.070618  34.316895
# 3941699  0.9048 -0.0194 -0.1454 -0.028107  0.010757  2.069855  34.330627
#
#             cresp  label
# 0       -1.383972    0.0
# 1       -1.397705    0.0
# ...

# %% [markdown]
# ##### Check Statistics

# %%
ch_df.describe().T
# Out:
#            count       mean       std        min        25%        50%  \
# cax    3941700.0   0.895513  0.029067   0.292600   0.887200   0.904800
# cay    3941700.0  -0.027159  0.048427  -0.470000  -0.055800  -0.029600
# caz    3941700.0  -0.124351  0.160252  -3.432800  -0.211400  -0.128800
# cecg   3941700.0   0.000438  0.355397  -1.401169  -0.141678  -0.046600
# cemg   3941700.0  -0.002816  0.011377  -0.220047  -0.009750  -0.002563
# ceda   3941700.0   2.143587  1.109629   0.637436   1.169968   1.977921
# ctemp  3941700.0  34.095200  0.252725  33.281677  33.923553  34.063538
# cresp  3941700.0   0.048976  3.420964 -25.285339  -2.134705  -0.222015
# label  3941700.0   1.382702  1.638328   0.000000   0.000000   1.000000
#
#              75%        max
# cax     0.913800   1.352200
# cay     0.001800   0.403800
# caz    -0.010200   2.356200
# cecg    0.027878   1.499954
# cemg    0.004303   0.183060
# ceda    2.315521   5.500412
# ctemp  34.322998  34.716980
# ...

# %% [markdown]
# ##### Check Type

# %%
ch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3941700 entries, 0 to 3941699
# Data columns (total 9 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   cax     float64
#  1   cay     float64
#  2   caz     float64
#  3   cecg    float64
#  4   cemg    float64
#  5   ceda    float64
#  6   ctemp   float64
#  7   cresp   float64
#  8   label   float64
# dtypes: float64(9)
# memory usage: 270.7 MB

# %% [markdown]
# ##### Check class counts

# %%
ch_df['label'].value_counts()
# Out:
# 0.0    1717100
# 1.0     826000
# 4.0     554399
# 2.0     471101
# 3.0     257600
# 6.0      39900
# 5.0      38500
# 7.0      37100
# Name: label, dtype: int64

# %% [markdown]
# ##### Show label classes sequence plot
#     Classes: 0 = Undefined, 1 = Baseline, 2 = Stress, 3 = Amusement, 4 = Meditation
#     Classes 5, 6, and 7 are periods in which questionnaires were given

# %%
ch_df[["label"]].plot(figsize=(15,2))
plt.text(400000,1.2,'Baseline'), plt.text(1550000,2.2,'"Stress"', c = 'darkred'), plt.text(2600000,4.2,'Meditation1', c = 'darkblue')
plt.text(3000000,3.3,'Amusement', c = 'darkgreen'), plt.text(3500000,4.2,'Meditation2', c = 'darkblue')
print(len(label))
# Out:
# 3941700

# %% [markdown]
# ## Grouped classes graphs

# %%
# ch_df.loc[ch_df['label'] == 7]
# 0 =  0, 3941699 'Undefined' and intermittent 
# 1 =  68859:894858 'Baseline' (826000, 9)
# 2 =  1391858:1862958 'Stress' (471101, 9)
# 3 =  3024259:3281858 'Amusement' (257600, 9)
# 4 =  2599359,  'Meditation' 1 start and 'Meditation' 2 end 4111482
# 5 =  928459:966958 (38500, 9)
# 6 =  2068059:2107958 (39900, 9)
# 7 =  3323859:3360958 (37100, 9)

# %% [markdown]
# ### Group by

# %%
Group = ch_df.groupby('label')
u1 = Group.get_group(0)
baseline = Group.get_group(1)
stress = Group.get_group(2)
amusement = Group.get_group(3)
meditation = Group.get_group(4)
u5 = Group.get_group(5) # in Yellow for timed questionnaire
u6 = Group.get_group(6) # in Yellow for timed questionnaire
u7 = Group.get_group(7) # in Yellow for timed questionnaire

# %%
b  = ('Baseline')
s = ('Stress')
a = ('Amusement')
m = ('Meditation')
r1 = 400000
r2 = 1550000
r3 = 3000000
r4 = 2600000
r5 = 3500000

# %% [markdown]
# ### Accelerometer graph

# %%
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplots(1,1)
plt.title('Accelerometer Axis X')
u1['cax'].plot(c = 'k'),baseline['cax'].plot(c = 'b'),stress['cax'].plot(c = 'r'),meditation['cax'].plot(c = 'm'),
amusement['cax'].plot(c = 'g'), u5['cax'].plot(c = 'y'),u6['cax'].plot(c = 'y'),u7['cax'].plot(c = 'y')
plt.text(r1,1,b), plt.text(r2,1.05,s), plt.text(r4,1,m), plt.text(r3,1.2,a), plt.text(r5,1,m);

plt.subplots(1,1)
plt.title('Accelerometer Axis Y')
u1['cay'].plot(c = 'k'),baseline['cay'].plot(c = 'b'),stress['cay'].plot(c = 'r'),meditation['cay'].plot(c = 'm')
amusement['cay'].plot(c = 'g'),u5['cay'].plot(c = 'y') ,u6['cay'].plot(c = 'y'),u7['cay'].plot(c = 'y');

plt.subplots(1,1)
plt.title('Accelerometer Axis Z')
u1['caz'].plot(c = 'k'),baseline['caz'].plot(c = 'b'),stress['caz'].plot(c = 'r'),amusement['caz'].plot(c = 'g')
meditation['caz'].plot(c = 'm'),u5['caz'].plot(c = 'y'),u6['caz'].plot( c= 'y'),u7['caz'].plot( c = 'y');

# %% [markdown]
# ### EDA, TEMP, RESP graphs

# %%
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplots(1,1)
plt.title('Electrodermal Activity')
u1['ceda'].plot(c= 'k'), baseline['ceda'].plot(c= 'b'),stress['ceda'].plot(c= 'r'),amusement['ceda'].plot(c= 'g')
meditation['ceda'].plot(c= 'm'),u5['ceda'].plot(c= 'y'),u6['ceda'].plot(c= 'y'),u7['ceda'].plot(c= 'y')
plt.text(r1,1.5,b), plt.text(r2,5,s), plt.text(r4,2.5,m),plt.text(r3,3,a), plt.text(r5,2.5,m);

plt.subplots(1,1)
plt.title('Skin Temperature')
u1['ctemp'].plot(c= 'k'),baseline['ctemp'].plot(c= 'b'),stress['ctemp'].plot(c= 'r'),amusement['ctemp'].plot(c= 'darkgreen')
meditation['ctemp'].plot(c= 'm'),u5['ctemp'].plot(c= 'y'),u6['ctemp'].plot(c= 'y'),u7['ctemp'].plot(c= 'y');

plt.subplots(1,1)
plt.title('Respiration')
u1['cresp'].plot(c= 'k'),baseline['cresp'].plot( c= 'b'),stress['cresp'].plot( c= 'r'),amusement['cresp'].plot(c= 'g')
meditation['cresp'].plot(c= 'm'),u5['cresp'].plot(c= 'y'),u6['cresp'].plot(c= 'y'),u7['cresp'].plot(c= 'y');

# %% [markdown]
# ### ECG and EMG graphs

# %%
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplots(1,1)
plt.title('Electrocardiogram')
u1['cecg'].plot(c= 'k'),baseline['cecg'].plot(c= 'b'),stress['cecg'].plot(c= 'r'),amusement['cecg'].plot(c= 'g')
meditation['cecg'].plot(c= 'm'),u5['cecg'].plot(c= 'y') ,u6['cecg'].plot(c= 'y') ,u7['cecg'].plot(c= 'y')
plt.text(r1,1.6,b), plt.text(r2,1.6,s), plt.text(r4,1.6,m),plt.text(r3,1.6,a), plt.text(r5,1.6,m); 

plt.subplots(1,1)
plt.title('Electromyogram')
u1['cemg'].plot(c= 'k'),baseline['cemg'].plot(c= 'b'),stress['cemg'].plot(c= 'r'),amusement['cemg'].plot(c= 'g')
meditation['cemg'].plot(c= 'm'),u5['cemg'].plot(c= 'y') ,u6['cemg'].plot(c= 'y') ,u7['cemg'].plot(c= 'y');

# %% [markdown]
# ## Concatenate classes 0, 1, 2, 3, and 4
#     Classes 5, 6 and 7 correspond to timed periods in which the participant answered questionnaires,
#     therefore, only classes 0, 1, 2, 3, and 4 will be used

# %%
loc0 = ch_df.loc[ch_df['label'] == 0]
loc1 = ch_df.loc[ch_df['label'] == 1]
loc2 = ch_df.loc[ch_df['label'] == 2]
loc3 = ch_df.loc[ch_df['label'] == 3]
loc4 = ch_df.loc[ch_df['label'] == 4]

# %%
ch_loc = pd.concat([loc0, loc1, loc2, loc3, loc4])
ch_loc
# Out:
#             cax     cay     caz      cecg      cemg      ceda      ctemp  \
# 0        0.7160  0.0856  1.6184  0.052780 -0.037445  0.963211  33.405396
# 1        0.6076  0.0392  1.5192  0.018539  0.006821  0.946426  33.428040
# 2        0.5252 -0.0142  1.3152 -0.037125  0.029068  0.980377  33.408447
# 3        0.4800 -0.0718  1.0126 -0.082260  0.002884  0.954437  33.420502
# 4        0.4638 -0.1342  0.6410 -0.101624 -0.014603  0.947571  33.414459
# ...         ...     ...     ...       ...       ...       ...        ...
# 3787954  0.8594 -0.0386 -0.3554  0.035751  0.011215  1.736069  34.414764
# 3787955  0.8574 -0.0374 -0.3498  0.039368  0.002747  1.726532  34.393311
# 3787956  0.8568 -0.0370 -0.3490  0.043442 -0.003067  1.725769  34.399475
# 3787957  0.8578 -0.0390 -0.3522  0.047836  0.006409  1.730347  34.399475
# 3787958  0.8582 -0.0390 -0.3556  0.055710 -0.010757  1.737595  34.405579
#
#             cresp  label
# 0       -1.383972    0.0
# 1       -1.397705    0.0
# ...

# %%
ch_loc.describe().T
# Out:
#            count       mean       std        min        25%        50%  \
# cax    3826200.0   0.894964  0.029295   0.292600   0.885800   0.904200
# cay    3826200.0  -0.027602  0.048911  -0.470000  -0.056600  -0.030200
# caz    3826200.0  -0.127123  0.161596  -3.432800  -0.214400  -0.134200
# cecg   3826200.0   0.000444  0.355511  -1.401169  -0.142227  -0.046555
# cemg   3826200.0  -0.002816  0.011419  -0.220047  -0.009750  -0.002563
# ceda   3826200.0   2.137410  1.113151   0.637436   1.152039   1.974487
# ctemp  3826200.0  34.096258  0.254667  33.281677  33.920502  34.068115
# cresp  3826200.0   0.047877  3.448199 -25.285339  -2.149963  -0.215149
# label  3826200.0   1.243688  1.444256   0.000000   0.000000   1.000000
#
#              75%        max
# cax     0.913800   1.352200
# cay     0.001200   0.403800
# caz    -0.011800   2.356200
# cecg    0.028793   1.499954
# cemg    0.004349   0.183060
# ceda    2.296448   5.500412
# ctemp  34.324493  34.716980
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Plot classes 0,1,2,3,4  vs. all classes

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (14,5))
plt.subplot(1, 2, 1)
ch_df['label'].value_counts().plot(kind='bar', 
                                     title='Chest Number of Examples by Class \n',
                                     color=['b','b','b','b','b','r','r','r'])
plt.subplot(1, 2, 2)
ch_loc['label'].value_counts().plot(kind='bar', 
                                     title='Chest Number of Examples by Class \n')
print((ch_df['label'].value_counts().sum()), ch_loc['label'].value_counts().sum())
print('Number of Rows Removed:', (ch_df['label'].value_counts().sum()) - 
      ch_loc['label'].value_counts().sum());
# Out:
# 3941700 3826200
# Number of Rows Removed: 115500

# %% [markdown]
#     The significant class imbalance has been reduced to a much less class imbalance

# %% [markdown]
# ### Correlation Plot

# %%
plt.figure(figsize=(9,7))
x_loc = ch_loc.drop('label',axis=1)
sns.heatmap(x_loc.corr(), annot=True, cmap=plt.cm.BuPu);

# %% [markdown]
#     There are no significant correlations
#     After Train/Test Split, check Train correlations

# %% [markdown]
# ### Pairs plots

# %%
treee = [cecg, cemg, ceda, ctemp, cresp] 
treee_array = np.array(treee) 
treee_array = treee_array.T
ch_treee = pd.DataFrame(treee_array,
                      columns = ['cecg', 'cemg', 'ceda',
                                 'ctemp', 'cresp'])

# %%
print('     ECG  EMG  EDA  TEMP  RESP ')
g = sns.pairplot(ch_treee)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)
# Out:
#      ECG  EMG  EDA  TEMP  RESP

# %% [markdown]
# ### Histogram with Boxplot

# %%
acc_array = np.array([cax, cay, caz, label]) 
acc_array = acc_array.T
ch_acc = pd.DataFrame(data = acc_array, columns=["cax", "cay", "caz", 'label'])
#ch_acc

# %%
# https://seaborn.pydata.org/tutorial/axis_grids.html
# https://stackoverflow.com/questions/34087126/plot-lower-triangle-in-a-seaborn-pairgrid
print('          3-Axis Acceleration XYZ')
g = sns.pairplot(ch_acc)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)
# Out:
#           3-Axis Acceleration XYZ

# %%
# 24 Histogram with a boxplot on top | seaborn
# https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw = {"height_ratios": (1, 10)})
sns.boxplot(ch_acc['cax'], ax=ax_box)
sns.distplot(ch_acc['cax'], ax=ax_hist)
ax_box.set(yticks = [])
sns.despine(ax = ax_hist)
sns.despine(ax = ax_box, left=True)

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw = {"height_ratios": (1, 10)})
sns.boxplot(ch_acc['cay'], ax=ax_box)
sns.distplot(ch_acc['cay'], ax=ax_hist)
ax_box.set(yticks = [])
sns.despine(ax = ax_hist)
sns.despine(ax = ax_box, left=True)

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw = {"height_ratios": (1, 10)})
sns.boxplot(ch_acc['caz'], ax=ax_box)
sns.distplot(ch_acc['caz'], ax=ax_hist)
ax_box.set(yticks = [])
sns.despine(ax = ax_hist)
sns.despine(ax = ax_box, left=True);

print(ch_acc[['cax', 'cay', 'caz']].describe().transpose())
print('Skew ----------------------------------')
print('cax2 skew:', ch_acc['cax'].skew())
print('cay2 skew:', ch_acc['cay'].skew())
print('caz2 skew:', ch_acc['caz'].skew());
# Out:
#          count      mean       std     min     25%     50%     75%     max
# cax  3941700.0  0.895513  0.029067  0.2926  0.8872  0.9048  0.9138  1.3522
# cay  3941700.0 -0.027159  0.048427 -0.4700 -0.0558 -0.0296  0.0018  0.4038
# caz  3941700.0 -0.124351  0.160252 -3.4328 -0.2114 -0.1288 -0.0102  2.3562
# Skew ----------------------------------
# cax2 skew: -0.6224076660297104
# cay2 skew: -0.22422508816396533
# caz2 skew: 0.4891060466344404

# %% [markdown]
# # Model Runs: XGBoost Classifier

# %% [markdown]
# <font size="3">
# XGBoost: an ensemble of gradient boosted decision trees that automatically reduces the feature set. It is probability-based and unaffected by scale factors, therefore requires no preprocessing such as normalization, standardization, or noise removal.
#
# An example of an automatic reduction of the feature set can be seen in the first two model runs below: allChest and shortChest.<br>
# Feature importance from the allChest (all features) model showed an extremely low influence by the Electromyogram attribute.<br>
# In the second model run, shortChest, the Electromyogram attribute was left out. However, scores for each model were essentially identical.</font>

# %% [markdown]
# <font size="3">
# Model runs included using all chest features, all chest features less electromyogram (EMG), chest features less accelerometer (ACC), accelerometer only, and electrodermal activity (EDA).
#
# Feature (attribute) choices and model runs for remaining 3 subject have been chosen bases-on the outputs from these test runs.
#
# Model feature combinations tests: <br>
#
# f1 Macro Average for somewhat imbalanced classes
#
# 1. All chest features model: Macro Average = 0.9845.
# 2. All chest features less electromyogram model also performed well with essentially identical results 1: Macro Average = 0.9844.
# 3. Chest features less accelerometer also showed good results, though not at the level of 1 and 2: Macro Average = 0.9348.
# 4. Accelerometer only: Macro Average = 0.7154.
# 5. Electrodermal Activity: Macro Average = 0.7435.
#
# Based on the results, feature combination choices include all chest features (allChest, chest features less accelerometer (lessAcc), Accelerometer only (ACC), and electrodermal activity (Eda) model runs are to be applied to the remaining Subjects S8, S11, and S13 for analysis.</font>

# %% [markdown]
# **XGBoost for Multi-class Classification** <br>
# https://towardsdatascience.com/xgboost-for-multi-class-classification-799d96bcd368
#
# **XGBoost Parameters**<br>
# https://xgboost.readthedocs.io/en/latest/parameter.html

# %% [markdown]
# ## Model allChest: All chest features

# %% [markdown]
# ### Train Test Split

# %%
y = ch_loc.label
x = ch_loc.drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape)
print(y_test.shape)
evalSet = [(x_train, y_train), (x_test, y_test)] # Need this to create plot
# Out:
# (3060960, 8)
# (765240,)

# %% [markdown]
# ### Check Train Correlations

# %%
plt.figure(figsize=(9,7))
sns.heatmap(x_train.corr(), annot=True, cmap=plt.cm.BuPu);

# %% [markdown]
#     There are no significant correlations in the train set

# %% [markdown]
# ### Model Fit

# %%
# https://stackoverflow.com/questions/42192227/xgboost-python-classifier-class-weight-option
# from sklearn.utils import class_weight
# class_weights = list(class_weight.compute_class_weight('balanced', np.unique(y),y))
# class_weights

## Applying class weights produced no discernible benefits

# %%
# %%time
# XGBoost Parameters
# https://xgboost.readthedocs.io/en/latest/parameter.html

allChest = XGBClassifier(objective = 'multi:softmax',
                              tree_method = 'gpu_hist',
                              learning_rate = 0.1,
                              n_estimators = 300, 
                              #max_depth = 10,
                              # deterministic_histogram = 'false',
                              gradient_based = 0.1,
                              num_early_stopping_rounds = 20,
                              gamma = 3,
                              seed = 35,
                              verbosity = 2) 

model_allChest = allChest.fit(x_train,y_train, 
                              eval_metric=['merror'], 
                              eval_set = evalSet)
# Out:
# [0]	validation_0-merror:0.04165	validation_1-merror:0.04192
# [1]	validation_0-merror:0.04109	validation_1-merror:0.04142
# [2]	validation_0-merror:0.03674	validation_1-merror:0.03705
# [3]	validation_0-merror:0.03634	validation_1-merror:0.03660
# [4]	validation_0-merror:0.03615	validation_1-merror:0.03624
# [5]	validation_0-merror:0.03573	validation_1-merror:0.03587
# [6]	validation_0-merror:0.03539	validation_1-merror:0.03557
# [7]	validation_0-merror:0.03514	validation_1-merror:0.03534
# [8]	validation_0-merror:0.03506	validation_1-merror:0.03524
# [9]	validation_0-merror:0.03479	validation_1-merror:0.03496
# [10]	validation_0-merror:0.03447	validation_1-merror:0.03458
# [11]	validation_0-merror:0.03437	validation_1-merror:0.03443
# [12]	validation_0-merror:0.03379	validation_1-merror:0.03385
# [13]	validation_0-merror:0.03367	validation_1-merror:0.03367
# [14]	validation_0-merror:0.03321	validation_1-merror:0.03324
# [15]	validation_0-merror:0.03303	validation_1-merror:0.03308
# ...

# %% [markdown]
# ###  Model Evaluation

# %% [markdown]
# #### Balanced Accuracy and Classification Report

# %%
allChest_pred = allChest.predict(x_test)
allChest_report = (classification_report(y_test,
                                         allChest_pred,
                                         labels=np.unique(allChest_pred),
                                         digits=4))

print('----------------------------------------')
print('Balanced Accuracy: {0:.4f}'.format(balanced_accuracy_score(y_test, allChest_pred)))
print('----------------------------------------')
print('------------ S16 All Chest Classification Report------------')
print(allChest_report)
# Out:
# ----------------------------------------
# Balanced Accuracy: 0.9873
# ----------------------------------------
# ------------ S16 All Chest Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.9894    0.9815    0.9854    343694
#          1.0     0.9940    0.9967    0.9953    165376
#          2.0     0.9926    0.9889    0.9907     93862
#          3.0     0.9503    0.9780    0.9639     51520
#          4.0     0.9815    0.9917    0.9866    110788
#
#     accuracy                         0.9869    765240
#    macro avg     0.9815    0.9873    0.9844    765240
# weighted avg     0.9870    0.9869    0.9869    765240

# %% [markdown]
# #### Multi-class Error Plot

# %%
# multi-class classification error plot 
# https://stackoverflow.com/questions/51900874/how-to-plot-xgboost-evaluation-metrics
sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = [10,6]
results = allChest.evals_result()
epochs = len(results['validation_0']['merror'])
x_axis = range(0, epochs)
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['merror'], label = 'Train', c = 'm')
ax.plot(x_axis, results['validation_1']['merror'], label = 'Test', c = 'r')
plt.legend(loc = 'upper right')
plt.ylabel('merror')
plt.xlabel('epochs')
plt.title('S16 XGBoost allChest Multiclass Error');

# %% [markdown]
#     Model stops improving at about 270 epochs.
#     Afterwards, test and train run parallel indicating that over-fitting is not present

# %% [markdown]
# #### cross validation and scaling check
# Although the XGBoost algorithm performs cross validation internally and scaling is not necessary, I'll run them here as a check

# %%
cross_val_score(allChest, x_train, y_train, scoring = "balanced_accuracy")
# Out:
# array([0.98678192, 0.98644053, 0.98644053, 0.98639152, 0.9865418 ])

# %%
# %%time
scaler  = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train.astype(np.float64))
cross_val_score(allChest, x_train_scaled, y_train, scoring = "f1_macro")
# Out:
# Wall time: 5min 58s
# array([0.9840501 , 0.98403263, 0.98417035, 0.98339166, 0.98403235])

# %% [markdown]
#     As expected, there was no improvement. Slightly reduced score, actually.

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(y_test, allChest_pred)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu )
print('------------ S16 All Chest Confusion matrix------------');
# Out:
# ------------ S16 All Chest Confusion matrix------------

# %% [markdown]
# #### Class Prediction Error

# %%
sns.set(style="darkgrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
print('------------ S16 All Chest Prediction Error------------')
error = ClassPredictionError(allChest, size=(620, 430), classes=Classes)
error.score(x_test, y_test)
e = error.poof()
# Out:
# ------------ S16 All Chest Prediction Error------------

# %% [markdown]
#     Class prediction error appears to be minimal

# %% [markdown]
# #### Multi-class AUC Score

# %%
# Multiclass ROC AUC Score original script sourced from
'''
Author: Plog, E
Title: AUC ROC Curve Scoring Function for Multi-class Classification
Date: 2018
Code version: n.a.
Availability: https://medium.com/@plog397/auc-roc-curve-scoring-function-for-multi-class-classification-9822871a6659
'''
# Out:
# '\nAuthor: Plog, E\nTitle: AUC ROC Curve Scoring Function for Multi-class Classification\nDate: 2018\nCode version: n.a.\nAvailability: https://medium.com/@plog397/auc-roc-curve-scoring-function-for-multi-class-classification-9822871a6659\n'

# %%
# false positive rate and true positive rate 
# (None, 'micro', 'macro', 'weighted', 'samples')
def multiclass_roc_auc_score(y_test, allChest_pred, average = 'micro'): 
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(allChest_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, allChest_pred)

print('S16 All Chest')
print('---------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S16 All Chest
# ---------------------
# AUC: 99.18%

# %% [markdown]
# #### Feature Importance

# %%
# ['weight', 'gain', 'cover', 'total_gain', 'total_cover']
sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = (7, 5) 
plot_importance(model_allChest, importance_type = 'weight', height = 0.7);

# %% [markdown]
#  ## Model shortChest: Less Electromyogram

# %% [markdown]
# ### Train Test Split

# %%
ch_short = ch_loc[['cax', 'cay', 'caz', 'ceda', 'ctemp', 'cresp', 'cecg', 'label']]
y = ch_short.label
x = ch_short.drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
evalSet = [(x_train, y_train), (x_test, y_test)]
print(x_train.shape)
print(y_test.shape)
# Out:
# (3060960, 7)
# (765240,)

# %% [markdown]
# ### Model Fit

# %%
# %%time
shortChest = XGBClassifier(objective = 'multi:softmax',
                              tree_method = 'gpu_hist',
                              learning_rate = 0.1,
                              n_estimators = 300, 
                              #max_depth = 10,
                              #deterministic_histogram = 'false',
                              gradient_based = 0.1,
                              num_early_stopping_rounds = 20,
                              gamma = 3,
                              #seed = 24,
                              verbosity = 2) 

model_shortChest = shortChest.fit(x_train,y_train,
                                 eval_metric=['merror'],
                                 eval_set = evalSet)

shortChest_pred = shortChest.predict(x_test)
shortChest_report = (classification_report(y_test,
                                           shortChest_pred,
                                           labels=np.unique(shortChest_pred),
                                           digits=4))
# Out:
# [0]	validation_0-merror:0.04286	validation_1-merror:0.04269
# [1]	validation_0-merror:0.03908	validation_1-merror:0.03915
# [2]	validation_0-merror:0.03706	validation_1-merror:0.03724
# [3]	validation_0-merror:0.03640	validation_1-merror:0.03664
# [4]	validation_0-merror:0.03614	validation_1-merror:0.03633
# [5]	validation_0-merror:0.03599	validation_1-merror:0.03618
# [6]	validation_0-merror:0.03581	validation_1-merror:0.03608
# [7]	validation_0-merror:0.03555	validation_1-merror:0.03585
# [8]	validation_0-merror:0.03528	validation_1-merror:0.03549
# [9]	validation_0-merror:0.03491	validation_1-merror:0.03511
# [10]	validation_0-merror:0.03451	validation_1-merror:0.03471
# [11]	validation_0-merror:0.03439	validation_1-merror:0.03457
# [12]	validation_0-merror:0.03406	validation_1-merror:0.03425
# [13]	validation_0-merror:0.03362	validation_1-merror:0.03377
# [14]	validation_0-merror:0.03326	validation_1-merror:0.03344
# [15]	validation_0-merror:0.03290	validation_1-merror:0.03309
# ...

# %% [markdown]
# ### Balanced Accuracy and Classification Report

# %%
print('Balanced Accuracy:', balanced_accuracy_score(y_test, shortChest_pred))
print('----------------------------------------')
print('------------ S16 All Chest less EMG Classification Report------------')
print(shortChest_report)
# Out:
# Balanced Accuracy: 0.9873260378650055
# ----------------------------------------
# ------------ S16 All Chest less EMG Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.9893    0.9814    0.9853    343189
#          1.0     0.9941    0.9966    0.9953    164907
#          2.0     0.9931    0.9893    0.9912     94434
#          3.0     0.9498    0.9776    0.9635     51752
#          4.0     0.9812    0.9918    0.9865    110958
#
#     accuracy                         0.9869    765240
#    macro avg     0.9815    0.9873    0.9844    765240
# weighted avg     0.9870    0.9869    0.9869    765240

# %% [markdown]
# ###  Multi-class Error Plot

# %%
sns.set(style="darkgrid")
plt.rcParams["figure.figsize"] = [10,6]
results = shortChest.evals_result()
epochs = len(results['validation_0']['merror'])
x_axis = range(0, epochs)
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['merror'], label = 'Train', c = 'm')
ax.plot(x_axis, results['validation_1']['merror'], label = 'Test', c = 'r')
plt.legend(loc = 'upper right')
plt.ylabel('merror')
plt.xlabel('epochs')
plt.title('S16 XGBoost Chest Multiclass Error');

# %% [markdown]
#     Oops! Forgot to change title

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test, shortChest_pred)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu );

# %% [markdown]
# ### Classification Prediction Error

# %%
sns.set(style="darkgrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
error = ClassPredictionError(shortChest, size=(620, 450), classes=Classes)
error.score(x_test, y_test)
e = error.poof()

# %% [markdown]
# ### Multiclass ROC AUC Score

# %%
def multiclass_roc_auc_score(y_test, shortChest_pred, average = 'micro'): 
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(shortChest_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, shortChest_pred)

print('S16 All Chest less ECG and EMG')
print('-------------------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S16 All Chest less ECG and EMG
# -------------------------------
# AUC: 99.19%

# %% [markdown]
# ## Model ch_lessAcc: Chest Less Accelerometer

# %% [markdown]
# ### Train Test Split

# %%
lessAcc = ch_loc[['ceda', 'ctemp', 'cresp', 'cemg', 'cecg', 'label']]
y = lessAcc.label
x = lessAcc.drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape)
print(y_test.shape)
# Out:
# (2845360, 5)
# (711341,)

# %% [markdown]
# ### Model Fit, Classification report, and Balanced Accuracy

# %%
# %%time
ch_lessAcc = XGBClassifier(objective = 'multi:softmax',
                              tree_method = 'gpu_hist',
                              learning_rate = 0.1,
                              n_estimators = 300, 
                              #max_depth = 10,
                              #deterministic_histogram = 'false',
                              gradient_based = 0.1,
                              num_early_stopping_rounds = 20,
                              gamma = 3,
                              #seed = 24,
                              verbosity = 2) 

model_ch_lessAcc = ch_lessAcc.fit(x_train,y_train)
ch_lessAcc_pred = ch_lessAcc.predict(x_test)
ch_lessAcc_report = (classification_report(y_test,
                                           ch_lessAcc_pred,
                                           labels=np.unique(ch_lessAcc_pred),
                                           digits=4))

print('Balanced Accuracy:', balanced_accuracy_score(y_test, ch_lessAcc_pred))
print('----------------------------------------')
print('------------ S16 All Chest less ACC Classification Report------------')
print(ch_lessAcc_report)
# Out:
# Balanced Accuracy: 0.9341677705058314
# ----------------------------------------
# ------------ S11 All Chest less ACC Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.9397    0.9104    0.9248    288788
#          1.0     0.9865    0.9967    0.9916    165141
#          2.0     0.9620    0.9769    0.9694     95378
#          3.0     0.8323    0.9014    0.8655     51378
#          4.0     0.8732    0.8855    0.8793    110656
#
#     accuracy                         0.9348    711341
#    macro avg     0.9187    0.9342    0.9261    711341
# weighted avg     0.9355    0.9348    0.9349    711341
#
# Wall time: 1min 12s

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test, ch_lessAcc_pred)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu );

# %% [markdown]
# ### Classification Prediction Error

# %%
sns.set(style="whitegrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
error = ClassPredictionError(ch_lessAcc, size=(620, 450), classes=Classes)
error.score(x_test, y_test)
e = error.poof()

# %% [markdown]
# ### Multiclass ROC AUC Score

# %%
def multiclass_roc_auc_score(y_test, ch_lessAcc_pred, average = 'micro'): 
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(ch_lessAcc_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, ch_lessAcc_pred)

print('S16 All Chest less ACC')
print('-------------------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S11 All Chest less ACC
# -------------------------------
# AUC: 95.93%

# %% [markdown]
# ## Model ACC: Accelerometer [X,Y,Z]

# %% [markdown]
# ### Train Test Split

# %%
ch_ACC = ch_loc[['cax', 'cay', 'caz', 'label']]
y = ch_ACC.label
x = ch_ACC.drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape)
print(y_test.shape)
# Out:
# (2845360, 3)
# (711341,)

# %% [markdown]
# ### Model Fit and f1 and Balanced Accuracy Scores

# %%
# %%time
ACC = XGBClassifier(objective = 'multi:softmax',
                           tree_method = 'gpu_hist',
                           learning_rate = 0.1,
                           gradient_based = 0.1,
                           num_early_stopping_rounds = 20,
                           n_estimators = 300,
                           gamma = 3,
                           verbosity = 2) 

model_ACC = ACC.fit(x_train, y_train)
ACC_pred = ACC.predict(x_test)
ACC_report = (classification_report(y_test, 
                                         ACC_pred, 
                                         labels=np.unique(ACC_pred),
                                         digits=4))

print('Balanced Accuracy:', balanced_accuracy_score(y_test, ACC_pred))
print('---------------------------------------')
print('------------ S16 Chest ACC Classification Report------------')
print(ACC_report)
# Out:
# Balanced Accuracy: 0.704588364527079
# ---------------------------------------
# ------------ S11 Chest ACC Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.7682    0.7487    0.7583    288867
#          1.0     0.7518    0.7870    0.7690    165088
#          2.0     0.6225    0.6415    0.6319     95295
#          3.0     0.7233    0.8006    0.7600     51515
#          4.0     0.5924    0.5451    0.5677    110576
#
#     accuracy                         0.7154    711341
#    macro avg     0.6916    0.7046    0.6974    711341
# weighted avg     0.7143    0.7154    0.7144    711341
#
# Wall time: 1min 11s

# %% [markdown]
# ### Confusion matrix

# %%
cm = confusion_matrix(y_test, ACC_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu );

# %% [markdown]
# ### Classification Prediction Error

# %%
sns.set(style="whitegrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
error = ClassPredictionError(ACC, size=(620, 450), classes=Classes)
error.score(x_test, y_test)
e = error.poof()

# %% [markdown]
# ### Multiclass ROC AUC Score

# %%
def multiclass_roc_auc_score(y_test, ACC_pred, average = 'macro'): #(None, 'micro', 'macro', 'weighted', 'samples')
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(ACC_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, ACC_pred)

print('S16 Chest Accelerometer')
print('-------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S11 Chest Accelerometer
# -------------------
# AUC: 81.37%

# %% [markdown]
# ## Individual Features
#     Test of two features: Skin Temperature and Electrodermal Activity
#     Electrodermal Activity performed the best with a macro average = 0.7252.
#     Therefore, of the 2 individual features tested, EDA will be used for the other Subjects

# %% [markdown]
# ### Model Eda: Electrodermal Activity only

# %% [markdown]
# #### Test Train Split

# %%
ch_eda= ch_loc[['ceda', 'label']]
y = ch_eda.label
x = ch_eda.drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape)
print(y_test.shape)
# Out:
# (2845360, 1)
# (711341,)

# %% [markdown]
# #### Model Fit, classification report, and balanced accuracy

# %%
# %%time
Eda = XGBClassifier(objective = 'multi:softmax',
                           tree_method = 'gpu_hist',
                           learning_rate = 0.1,
                           gradient_based = 0.1,
                           num_early_stopping_rounds = 30,
                           n_estimators = 300,
                           gamma = 3,
                           verbosity = 2) 

model_Eda = Eda.fit(x_train, y_train)
Eda_pred = Eda.predict(x_test)
Eda_report = (classification_report(y_test, 
                                         Eda_pred, 
                                         labels = np.unique(Eda_pred),
                                         digits = 4))

print('Balanced Accuracy:', balanced_accuracy_score(y_test, Eda_pred))
print('---------------------------------------')
print('------------ S11 Chest Electrodermal Activity Classification Report------------')
print(Eda_report)
# Out:
# Balanced Accuracy: 0.7196002492380293
# ---------------------------------------
# ------------ S11 Chest Electrodermal Activity Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.7170    0.7447    0.7306    288953
#          1.0     0.9677    0.8868    0.9255    165886
#          2.0     0.6842    0.5660    0.6195     94750
#          3.0     0.7232    0.7049    0.7140     51549
#          4.0     0.5869    0.6956    0.6367    110203
#
#     accuracy                         0.7435    711341
#    macro avg     0.7358    0.7196    0.7252    711341
# weighted avg     0.7514    0.7435    0.7455    711341
#
# Wall time: 43.3 s

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test, Eda_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu );

# %% [markdown]
# #### Classification Prediction Error

# %%
sns.set(style="whitegrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
error = ClassPredictionError(Eda, size=(620, 450), classes=Classes)
error.score(x_test, y_test)
e = error.poof()

# %% [markdown]
# #### Multiclass ROC AUC Score

# %%
def multiclass_roc_auc_score(y_test, Eda_pred, average = 'macro'): #(None, 'micro', 'macro', 'weighted', 'samples')
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(Eda_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, Eda_pred)

print('S11 Chest Skin Temperature')
print('-------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S11 Chest Skin Temperature
# -------------------
# AUC: 82.37%

# %% [markdown]
# ### Model Temp: Skin Temperature

# %% [markdown]
# #### Test Train Split

# %%
ch_temp = ch_loc[['ctemp', 'label']]
y = ch_temp .label
x = ch_temp .drop('label',axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape)
print(y_test.shape)
# Out:
# (3060960, 1)
# (765240,)

# %% [markdown]
# #### Model Fit, classification report, and Balanced Accuracy

# %%
# %%time
Temp = XGBClassifier(objective = 'multi:softmax',
                           tree_method = 'gpu_hist',
                           learning_rate = 0.1,
                           gradient_based = 0.1,
                           num_early_stopping_rounds = 30,
                           n_estimators = 300,
                           gamma = 3,
                           verbosity = 2) 

model_Temp = Temp.fit(x_train, y_train)
Temp_pred = Temp.predict(x_test)
Temp_report = (classification_report(y_test, 
                                         Temp_pred, 
                                         labels = np.unique(Temp_pred),
                                         digits = 4))

print('Balanced Accuracy:', balanced_accuracy_score(y_test, Temp_pred))
print('---------------------------------------')
print('------------ S11 Chest Skin Temperature Classification Report------------')
print(Temp_report)
# Out:
# Balanced Accuracy: 0.5557110159099753
# ---------------------------------------
# ------------ S11 Chest Skin Temperature Classification Report------------
#               precision    recall  f1-score   support
#
#          0.0     0.6245    0.6855    0.6536    343105
#          1.0     0.7194    0.5585    0.6288    165327
#          2.0     0.4606    0.5353    0.4952     94251
#          3.0     0.5105    0.4762    0.4927     51819
#          4.0     0.5659    0.5231    0.5436    110738
#
#     accuracy                         0.6019    765240
#    macro avg     0.5762    0.5557    0.5628    765240
# weighted avg     0.6086    0.6019    0.6019    765240
#
# Wall time: 50 s

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test, Temp_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.BuPu );

# %% [markdown]
# #### Classification Prediction Error

# %%
sns.set(style="darkgrid")
Classes = ['0', 'base', 'stress', 'amus', 'med']
error = ClassPredictionError(Temp, size=(620, 450), classes=Classes)
error.score(x_test, y_test)
e = error.poof()

# %% [markdown]
# #### Multiclass ROC AUC Score

# %%
def multiclass_roc_auc_score(y_test, Temp_pred, average = 'macro'): #(None, 'micro', 'macro', 'weighted', 'samples')
    xg = preprocessing.LabelBinarizer()
    xg.fit(y_test)
    y_test1 = xg.transform(y_test) 
    y_pred1 = xg.transform(Temp_pred)
    return roc_auc_score(y_test1, y_pred1, average=average)

aucScore = multiclass_roc_auc_score(y_test, Temp_pred)

print('S11 Chest Skin Temperature')
print('-------------------')
print("AUC: %.2f%%" % (aucScore*100))
# Out:
# S11 Chest Skin Temperature
# -------------------
# AUC: 71.94%

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Macro Average Scores, Mean, and Standard Deviation across 4 Subjects
# For this data, Macro average is the better choice than f1 accuracy and other scores for this somewhat imbalanced classes
# <!--       Balanced accuracy is also often used for imbalanced classes
#       The AUC score was added to highlight what it might look like if the classes were much better balanced  -->

# %%
macroAvg = pd.read_excel('D:WESAD/subject_metrics.xlsx', 
                             index_col=0,sheet_name='Stats',
                             dtype={'Name': str, 'Value': float})

macroAvg
# Out:
#                S8     S11     S13     S16    mean      std
# allChest   0.9910  0.9817  0.9928  0.9844  0.9875  0.00526
# chLessAcc  0.8001  0.9290  0.9370  0.9261  0.8981  0.06546
# ACC        0.9188  0.7014  0.7845  0.6974  0.7755  0.10361
# EDA        0.5860  0.7237  0.9151  0.7252  0.7374  0.13539

# %% [markdown]
# Clearly, using all chest features produces the best prediction result

# %% [markdown]
# ### Stress condition scores
#     The number of subjects is too low to make any reliable analyses.
#     However, the analyses are presented here as an example of what else might be accomplished using this type of data.
#     Stress is a single class, therefore an f1 score is appropriate for analysis.

# %% [markdown]
# #### across all 4 Subjects
#     To determine the feature or feature combination that is the best predictor of stress

# %%
all_macro_averages = pd.read_excel('D:WESAD/subject_metrics.xlsx', index_col=0,sheet_name='all_macro_avgs',
              dtype={'Name': str, 'Value': float})
all_macro_averages
# Out:
#                S4      S8     S11     S13     S16     S17      mean       std
# allChest   0.9897  0.9910  0.9817  0.9928  0.9844  0.9919  0.988583  0.004489
# chLessAcc  0.9330  0.8001  0.9290  0.9370  0.9261  0.9410  0.911033  0.054609
# ACC        0.9105  0.9188  0.7014  0.7845  0.6974  0.8862  0.816467  0.102583
# EDA        0.7304  0.5860  0.7237  0.9151  0.7252  0.7820  0.743733  0.106427

# %% [markdown]
# Using all sensors when compared to splitting the sensor data is the best predictor of stress

# %%
from statistics import mean
import statistics

# %% [markdown]
# #### Comfort during Stress f1 scores
#      Analysis of difference between comfort levels.
#      in this case comfort level was between feeling cold and not feeling cold during the stress test
#      Not_cold = 0, Cold = 1

# %%
stress_by_comfort_level = pd.read_excel('D:WESAD/subject_metrics.xlsx', index_col=0,sheet_name='comfort_level',
              dtype={'Name': str, 'Value': float})
stress_by_comfort_level
# Out:
#      f1_stress  comfort_level
# S16     0.9912              1
# S8      0.9893              1
# S4      0.9887              0
# S11     0.9947              0
# S13     0.9940              0
# S17     0.9990              0

# %%
print('Felt cold during Stress conditioning: Mean = ', round(mean(stress_by_comfort_level['f1_stress'][0:2]),4))
print('Did not feel cold during Stress conditioning: Mean = ', round(mean(stress_by_comfort_level['f1_stress'][2:6]),4))
# Out:
# Felt cold during Stress conditioning: Mean =  0.9902
# Did not feel cold during Stress conditioning: Mean =  0.9941

# %% [markdown]
#     There appears to be a slight but not significant difference between comfort levels during the stress conditioning

# %% [markdown]
# ###  Stress vs
#      Analysis of difference between gender: Female = 0, Male = 1

# %% [markdown]
# #### Gender Stress f1 scores
#      Analysis of difference between gender: Female = 0, Male = 1

# %%
stress_by_gender = pd.read_excel('D:WESAD/subject_metrics.xlsx', index_col=0,sheet_name='gender',
              dtype={'Name': str, 'Value': float})
stress_by_gender
# Out:
#   subject  f1_stress  f1_baseline  f1_avg  macroAvg  gender gender_
# 0      S4     0.9887       0.9975  0.9923    0.9897       1    male
# 1     S13     0.9940       0.9977  0.9936    0.9928       1    male
# 2     S16     0.9912       0.9953  0.9869    0.9844       1    male
# 3      S8     0.9893       0.9965  0.9915    0.9910       0  female
# 4     S11     0.9947       0.9961  0.9822    0.9817       0  female
# 5     S17     0.9990       0.9986  0.9936    0.9919       0  female

# %% [markdown]
# #### Stress vs Baseline

# %%
# https://docs.bokeh.org/en/latest/docs/gallery/bar_dodged.html
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

# %% [markdown]
# ##### Graph Stress vs Baseline

# %%
subject = stress_by_gender['subject']
g = figure(x_range=subject, y_range=(0.97, 1), plot_height=350, title="Stress vs. Baseline",
           toolbar_location=None, tools="")

g.vbar(x=dodge('subject', -0.25, range=g.x_range), top='f1_stress', width=0.2, source=stress_by_gender,
       color="mediumturquoise", legend_label="f1_stress")

g.vbar(x=dodge('subject',  0.0,  range=g.x_range), top='f1_baseline', width=0.2, source=stress_by_gender,
       color="#718dbf", legend_label="f1_baseline")

g.vbar(x=dodge('subject',  0.25,  range=g.x_range), top='f1_avg', width=0.2, source=stress_by_gender,
       color="lightslategray", legend_label="f1_avg")

g.x_range.range_padding = 0.1
g.xgrid.grid_line_color = None
g.legend.location = "top_left"
g.legend.orientation = "horizontal"

show(g)

# %%
from IPython.display import Image
Image(width = 700, filename = 'D:/WESAD/Stress vs Baseline.png')

# %% [markdown]
# ##### Mean Stress vs Baseline

# %%
print('Stress: Mean = ', round(mean(stress_by_gender['f1_stress']),4))
print('Baseline: Mean = ', round(mean(stress_by_gender['f1_baseline']),4))
print('f1 Average: Mean = ', round(mean(stress_by_gender['f1_avg']),4))
# Out:
# Stress: Mean =  0.9928
# Baseline: Mean =  0.997
# f1 Average: Mean =  0.99

# %% [markdown]
# #### Graph Stress vs Baseline by Gender
#     This graph was made using an excel pivot table.
#     Same information as the previous (bokeh) graph but with gender class included.

# %%
Image(width = 700, filename = 'D:/WESAD/Stress_by_Gender.png')

# %% [markdown]
# ##### Mean stress female vs male

# %%
from statistics import mean
print('Male Stress: Mean = ', round(mean(stress_by_gender['f1_stress'][0:3]),4))
print('Female Stress: Mean = ', round(mean(stress_by_gender['f1_stress'][3:6]),4))
print('-----------------------------')
print('Male Baseline: Mean = ', round(mean(stress_by_gender['f1_baseline'][0:3]),4))
print('Femal Baseline: Mean = ', round(mean(stress_by_gender['f1_baseline'][3:6]),4))
# Out:
# Male Stress: Mean =  0.9913
# Female Stress: Mean =  0.9943
# -----------------------------
# Male Baseline: Mean =  0.9968
# Femal Baseline: Mean =  0.9971

# %% [markdown]
#     Baseline conditioning between male and female are essentially identical.
#     There appears to be a slight but not significant difference between male and female during the stress conditioning,
